# %%
from pyspark.sql import Row

# Sample data
data = [
    Row(name="Vegash", age=22, city="Bangalore"),
    Row(name="Arun", age=25, city="Chennai"),
    Row(name="Riya", age=21, city="Mumbai")
]

# Create DataFrame
df = spark.createDataFrame(data)

# Show DataFrame
df.show()
